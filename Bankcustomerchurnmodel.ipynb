# %% [markdown]
# **Import** **Library**

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# **import** **Data**

# %%
df = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Bank%20Churn%20Modelling.csv')

# %% [markdown]
# **Analyse Data**

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  Num Of Products  Has Credit Card  Is Active Member  \
# 0       0.00                1                1                 1
# 1   83807.86                1                0                 1
# 2  159660.80                3                1                 0
# 3       0.00                2                0                 0
# 4  125510.82                1                1                 1
#
#    Estimated Salary  Churn
# 0         101348.88      1
# 1         112542.58      0
# 2         113931.57      1
# 3          93826.63      0
# 4          79084.10      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerId        10000 non-null  int64
#  1   Surname           10000 non-null  object
#  2   CreditScore       10000 non-null  int64
#  3   Geography         10000 non-null  object
#  4   Gender            10000 non-null  object
#  5   Age               10000 non-null  int64
#  6   Tenure            10000 non-null  int64
#  7   Balance           10000 non-null  float64
#  8   Num Of Products   10000 non-null  int64
#  9   Has Credit Card   10000 non-null  int64
#  10  Is Active Member  10000 non-null  int64
#  11  Estimated Salary  10000 non-null  float64
#  12  Churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
df.duplicated('CustomerId').sum()
# Out:
# 0

# %%
df = df.set_index('CustomerId')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 15634602 to 15628319
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Surname           10000 non-null  object
#  1   CreditScore       10000 non-null  int64
#  2   Geography         10000 non-null  object
#  3   Gender            10000 non-null  object
#  4   Age               10000 non-null  int64
#  5   Tenure            10000 non-null  int64
#  6   Balance           10000 non-null  float64
#  7   Num Of Products   10000 non-null  int64
#  8   Has Credit Card   10000 non-null  int64
#  9   Is Active Member  10000 non-null  int64
#  10  Estimated Salary  10000 non-null  float64
#  11  Churn             10000 non-null  int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 1015.6+ KB

# %% [markdown]
# **Encoding**

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df.replace({'Geography': {'France':2, 'Germany':1, 'Spain':0}}, inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df.replace({'Gender': {'Male':0, 'Female':1}}, inplace=True)

# %%
df['Num Of Products'].value_counts()
# Out:
# Num Of Products
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: count, dtype: int64

# %%
df.replace({'Num Of Products': {1:0, 2:1, 3:0, 4:1 }}, inplace=True)

# %%
df['Has Credit Card'].value_counts()
# Out:
# Has Credit Card
# 1    7055
# 0    2945
# Name: count, dtype: int64

# %%
df['Is Active Member'].value_counts()
# Out:
# Is Active Member
# 1    5151
# 0    4849
# Name: count, dtype: int64

# %%
df.loc[(df['Balance']==0), 'Churn'].value_counts()
# Out:
# Churn
# 0    3117
# 1     500
# Name: count, dtype: int64

# %%
df['Zero Balance'] = np.where(df['Balance']>0, 1, 0)

# %%
df['Zero Balance'].hist()
# Out:
# <Axes: >

# %%
df.groupby(['Churn', 'Geography']).count()
# Out:
#                  Surname  CreditScore  Gender   Age  Tenure  Balance  \
# Churn Geography
# 0     0             2064         2064    2064  2064    2064     2064
#       1             1695         1695    1695  1695    1695     1695
#       2             4204         4204    4204  4204    4204     4204
# 1     0              413          413     413   413     413      413
#       1              814          814     814   814     814      814
#       2              810          810     810   810     810      810
#
#                  Num Of Products  Has Credit Card  Is Active Member  \
# Churn Geography
# 0     0                     2064             2064              2064
#       1                     1695             1695              1695
#       2                     4204             4204              4204
# 1     0                      413              413               413
#       1                      814              814               814
#       2                      810              810               810
#
#                  Estimated Salary  Zero Balance
# Churn Geography
# 0     0                      2064          2064
#       1                      1695          1695
#       2                      4204          4204
# 1     0                       413           413
#       1                       814           814
#       2                       810           810

# %% [markdown]
# **Define Label and Features**

# %%
df.columns
# Out:
# Index(['Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'Num Of Products', 'Has Credit Card', 'Is Active Member',
#        'Estimated Salary', 'Churn', 'Zero Balance'],
#       dtype='object')

# %%
x = df.drop(['Surname','Churn'], axis = 1)
y = df['Churn']

# %%
x.shape, y.shape
# Out:
# ((10000, 11), (10000,))

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Churn', data = df);

# %%
x.shape, y.shape
# Out:
# ((10000, 11), (10000,))

# %% [markdown]
# **Random Under Sampling**

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rus = RandomUnderSampler(random_state=2529)
x_rus, y_rus = rus.fit_resample(x,y)

# %%
x_rus.shape, y_rus.shape, x.shape, y.shape
# Out:
# ((4074, 11), (4074,), (10000, 11), (10000,))

# %%
y.value_counts()
# Out:
# Churn
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
y_rus.value_counts()
# Out:
# Churn
# 0    2037
# 1    2037
# Name: count, dtype: int64

# %%
y_rus.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Random Over Sampling**

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomUnderSampler(random_state=2529)

# %%
x_ros, y_ros = ros.fit_resample(x,y)

# %%
x_ros.shape, y_ros.shape, x.shape, y.shape
# Out:
# ((4074, 11), (4074,), (10000, 11), (10000,))

# %%
y.value_counts()
# Out:
# Churn
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
y_ros.value_counts()
# Out:
# Churn
# 0    2037
# 1    2037
# Name: count, dtype: int64

# %%
y_ros.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Split Original Data**

# %%
x_train, x_test, y_train, y_test, = train_test_split(x, y, test_size=0.3, random_state=2529)

# %% [markdown]
# **Split Random Under Sample Data**

# %%
x_train_rus, x_test_rus, y_train_rus, y_test_rus = train_test_split(x_rus, y_rus, test_size=0.3, random_state=2529)

# %% [markdown]
# **Split Random Over Sample Data**

# %%
x_train_ros, x_test_ros, y_train_ros, y_test_ros = train_test_split(x_ros, y_ros, test_size=0.3, random_state=2529)

# %% [markdown]
# **Standardize Features**

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %% [markdown]
# **Standardize Original Data**

# %%
x_train[['CreditScore', 'Age', 'Tenure', 'Balance', 'Estimated Salary']] = sc.fit_transform(x_train[['CreditScore', 'Age', 'Tenure', 'Balance', 'Estimated Salary']])

# %%
x_test[['CreditScore', 'Age', 'Tenure', 'Balance', 'Estimated Salary']] = sc.fit_transform(x_test[['CreditScore', 'Age', 'Tenure', 'Balance', 'Estimated Salary']])

# %% [markdown]
# **Standardize Random Under Sample Data**

# %%
x_train_rus[['CreditScore', 'Age', 'Tenure', 'Balance', 'Estimated Salary']] = sc.fit_transform(x_train_rus[['CreditScore', 'Age', 'Tenure', 'Balance', 'Estimated Salary']])

# %%
x_test_rus[['CreditScore', 'Age', 'Tenure', 'Balance', 'Estimated Salary']] = sc.fit_transform(x_test_rus[['CreditScore', 'Age', 'Tenure', 'Balance', 'Estimated Salary']])

# %% [markdown]
# **Random Over Sample Data**

# %%
x_train_ros[['CreditScore', 'Age', 'Tenure', 'Balance', 'Estimated Salary']] = sc.fit_transform(x_train_ros[['CreditScore', 'Age', 'Tenure', 'Balance', 'Estimated Salary']])
x_test_ros[['CreditScore', 'Age', 'Tenure', 'Balance', 'Estimated Salary']] = sc.fit_transform(x_test_ros[['CreditScore', 'Age', 'Tenure', 'Balance', 'Estimated Salary']])

# %% [markdown]
# **Support Vector Machine Classifier**

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred = svc.predict(x_test)

# %% [markdown]
# **Model Accuracy**

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[2375,   39],
#        [ 410,  176]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91      2414
#            1       0.82      0.30      0.44       586
#
#     accuracy                           0.85      3000
#    macro avg       0.84      0.64      0.68      3000
# weighted avg       0.85      0.85      0.82      3000

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01],
              'kernel': ['rbf'],
              'class_weight': ['balanced']}

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   3.3s
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.7s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.6s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.7s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.6s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.9s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.8s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.8s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.8s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   2.4s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   1.9s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   1.9s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   3.1s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   1.9s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   2.3s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.6s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.5s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.5s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.5s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.6s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.8s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   2.4s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.5s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.1s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.1s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=   3.1s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.7s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.7s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.7s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.7s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.7s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   2.3s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.8s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.5s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.5s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.5s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.1s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=   3.0s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.1s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   4.3s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   5.3s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   4.5s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   5.2s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   4.9s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   2.1s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   2.1s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   2.9s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV] END .C=1000, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.1s
# [CV] END .C=1000, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.1s
# [CV] END .C=1000, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.1s
# [CV] END .C=1000, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.6s
# [CV] END .C=1000, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.7s
# [CV] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  24.4s
# [CV] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  25.5s
# [CV] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  26.8s
# [CV] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  27.3s
# [CV] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  27.2s
# [CV] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   6.5s
# [CV] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   5.5s
# [CV] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   6.4s
# [CV] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   5.6s
# [CV] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   5.9s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'class_weight': ['balanced'], 'gamma': [1, 0.1, 0.01],
#                          'kernel': ['rbf']},
#              verbose=2)

# %%
print(grid.best_estimator_)
# Out:
# SVC(C=0.1, class_weight='balanced', gamma=1)

# %%
grid_predictions = grid.predict(x_test)

# %%
confusion_matrix(y_test,grid_predictions)
# Out:
# array([[2038,  376],
#        [ 233,  353]])

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87      2414
#            1       0.48      0.60      0.54       586
#
#     accuracy                           0.80      3000
#    macro avg       0.69      0.72      0.70      3000
# weighted avg       0.82      0.80      0.80      3000

# %% [markdown]
# **Model with Random Under Sampling**

# %%
svc_rus = SVC()

# %%
svc_rus.fit(x_train_rus, y_train_rus)
# Out:
# SVC()

# %%
y_pred_rus = svc_rus.predict(x_test_rus)

# %% [markdown]
# **Model Accuracy**

# %%
confusion_matrix(y_test_rus, y_pred_rus)
# Out:
# array([[450, 177],
#        [151, 445]])

# %%
confusion_matrix(y_test_rus, y_pred_rus)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.73       627
#            1       0.72      0.75      0.73       596
#
#     accuracy                           0.73      1223
#    macro avg       0.73      0.73      0.73      1223
# weighted avg       0.73      0.73      0.73      1223

# %% [markdown]
# **Hyperparameter Tunning**

# %%
param_grid = {'C': [0.1,1, 10] ,
              'gamma': [1,0.1,0.01] ,
              'kernel': ['rbf'],
              'class_weight': ['balanced']}

# %%
grid_rus = GridSearchCV(SVC(),param_grid,refit=True,verbose=2, cv = 2)
grid_rus.fit(x_train_rus,y_train_rus)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.3s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.2s
# GridSearchCV(cv=2, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10], 'class_weight': ['balanced'],
#                          'gamma': [1, 0.1, 0.01], 'kernel': ['rbf']},
#              verbose=2)

# %%
print(grid_rus.best_estimator_)
# Out:
# SVC(C=1, class_weight='balanced', gamma=0.1)

# %%
grid_predictions_rus = grid_rus.predict(x_test_rus)

# %%
confusion_matrix(y_test_rus,grid_predictions_rus)
# Out:
# array([[453, 174],
#        [154, 442]])

# %%
print(classification_report(y_test_rus,grid_predictions_rus))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.73       627
#            1       0.72      0.74      0.73       596
#
#     accuracy                           0.73      1223
#    macro avg       0.73      0.73      0.73      1223
# weighted avg       0.73      0.73      0.73      1223

# %% [markdown]
# **Model with Random Over Sampling**

# %%
svc_ros = SVC()

# %%
svc_ros.fit(x_train_ros, y_train_ros)
# Out:
# SVC()

# %%
y_pred_ros = svc_ros.predict(x_test_ros)

# %% [markdown]
# **Model Accuracy**

# %%
confusion_matrix(y_test_ros, y_pred_ros)
# Out:
# array([[450, 177],
#        [151, 445]])

# %%
confusion_matrix(y_test_ros, y_pred_ros)
# Out:
# array([[450, 177],
#        [151, 445]])

# %% [markdown]
# **Hyperparameter Tunning**

# %%
param_grid = {'C': [0.1,1, 10] ,
              'gamma': [1,0.1,0.01] ,
              'kernel': ['rbf'],
              'class_weight': ['balanced']}

# %%
grid_ros = GridSearchCV(SVC(),param_grid,refit=True,verbose=2, cv = 2)
grid_ros.fit(x_train_ros,y_train_ros)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.7s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.2s
# GridSearchCV(cv=2, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10], 'class_weight': ['balanced'],
#                          'gamma': [1, 0.1, 0.01], 'kernel': ['rbf']},
#              verbose=2)

# %%
print(grid_ros.best_estimator_)
# Out:
# SVC(C=1, class_weight='balanced', gamma=0.1)

# %%
grid_predictions_ros = grid_ros.predict(x_test_ros)

# %%
confusion_matrix(y_test_ros,grid_predictions_ros)
# Out:
# array([[453, 174],
#        [154, 442]])

# %%
print(classification_report(y_test_ros,grid_predictions_ros))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.73       627
#            1       0.72      0.74      0.73       596
#
#     accuracy                           0.73      1223
#    macro avg       0.73      0.73      0.73      1223
# weighted avg       0.73      0.73      0.73      1223

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91      2414
#            1       0.82      0.30      0.44       586
#
#     accuracy                           0.85      3000
#    macro avg       0.84      0.64      0.68      3000
# weighted avg       0.85      0.85      0.82      3000

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87      2414
#            1       0.48      0.60      0.54       586
#
#     accuracy                           0.80      3000
#    macro avg       0.69      0.72      0.70      3000
# weighted avg       0.82      0.80      0.80      3000

# %%
print(classification_report(y_test_rus,y_pred_rus))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.73       627
#            1       0.72      0.75      0.73       596
#
#     accuracy                           0.73      1223
#    macro avg       0.73      0.73      0.73      1223
# weighted avg       0.73      0.73      0.73      1223

# %%
print(classification_report(y_test_rus,grid_predictions_rus))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.73       627
#            1       0.72      0.74      0.73       596
#
#     accuracy                           0.73      1223
#    macro avg       0.73      0.73      0.73      1223
# weighted avg       0.73      0.73      0.73      1223

# %%
print(classification_report(y_test_ros,y_pred_ros))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.73       627
#            1       0.72      0.75      0.73       596
#
#     accuracy                           0.73      1223
#    macro avg       0.73      0.73      0.73      1223
# weighted avg       0.73      0.73      0.73      1223

# %%
print(classification_report(y_test_ros,grid_predictions_ros))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.73       627
#            1       0.72      0.74      0.73       596
#
#     accuracy                           0.73      1223
#    macro avg       0.73      0.73      0.73      1223
# weighted avg       0.73      0.73      0.73      1223
